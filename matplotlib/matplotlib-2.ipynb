# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introduction to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
# plt.plot(3,3)

# %%
plt.plot();

# %%
plt.show()

# %%
plt.plot([1,2,3,4,5]);

# %%
plt.show()

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %%
plt.plot(x,y)

# %%
plt.show()

# %% [markdown]
# ## the above plotting is called as the stateless plotting

# %%
plt.show()

# %% [markdown]
# ### pyplot api is less flexible than object-oriented api

# %%
#try to use the objectoriented interface than pyplot interface

# %%
fig=plt.figure()

# %%
ax=fig.add_subplot()

# %%
plt.show()

# %%
#second method

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])

# %%
ax.plot(x,y)
plt.show()

# %%
## 3rd method(recommended)

# %%
fig,ax=plt.subplots()
ax.plot(x,y);

# %%
plt.show()

# %%
sfig,sax=plt.subplots()

# %%
sax.plot(x,[50,100,200,400])

# %%
plt.show()

# %% [markdown]
# ## use always method 3 for the plotting

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# the both outputs above will represent the object oriented display

# %% [markdown]
# # matplotlob example workflow

# %% [markdown]
# # 0. preparing the import if the matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.prepare data

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %% [markdown]
# # 2.setupplot

# %%
fig,ax=plt.subplots(figsize=(5,10))

# %%
# here figsize is the width and height respectively of the plot

# %% [markdown]
# # 3. plot the data

# %%
ax.plot(x,y)

# %% [markdown]
# # 4. customize the plot

# %%
ax.set(title='sample plot',xlabel='x-axis',ylabel='y-axis')
# Out:
# [Text(0.5, 1.0, 'sample plot'),
#  Text(0.5, 4.4444444444444375, 'x-axis'),
#  Text(4.4444444444444375, 0.5, 'y-axis')]

# %%
plt.show()

# %%
#fig.savefig("/Users/chowdaryadithyasaividivada/desktop/sample.png")

# %%
import numpy as np

# %%
s1=np.random.rand(100)

# %%
s1
# Out:
# array([0.07914405, 0.27574492, 0.65714422, 0.31850829, 0.92059799,
#        0.45339487, 0.93155586, 0.08216264, 0.16579032, 0.09476118,
#        0.75873144, 0.32596553, 0.27246629, 0.31091397, 0.86106224,
#        0.0756581 , 0.17755041, 0.26156474, 0.87870833, 0.98121658,
#        0.15756681, 0.13833397, 0.52261569, 0.17937718, 0.36717149,
#        0.41311497, 0.35436658, 0.15706486, 0.10006842, 0.86840654,
#        0.21571075, 0.18067704, 0.03991541, 0.78855399, 0.85377661,
#        0.05172343, 0.56232118, 0.57111775, 0.00607639, 0.02642943,
#        0.9324685 , 0.83263613, 0.31587896, 0.02351458, 0.58687011,
#        0.14718555, 0.84607831, 0.29941745, 0.71577651, 0.55487663,
#        0.21605593, 0.70152055, 0.80862562, 0.71190473, 0.41427751,
#        0.57789347, 0.07179218, 0.40225778, 0.26413119, 0.53797699,
#        0.27839627, 0.47328096, 0.17942239, 0.87873654, 0.68319274,
#        0.34737037, 0.8350912 , 0.42590819, 0.1706662 , 0.78246596,
# ...

# %%
s1.ndim
# Out:
# 1

# %%
s2=np.random.rand(100,200)

# %%
s2
# Out:
# array([[0.91513618, 0.15472405, 0.96938258, ..., 0.47600345, 0.94568276,
#         0.64221808],
#        [0.83321699, 0.49245824, 0.21385685, ..., 0.01997197, 0.41309892,
#         0.99750702],
#        [0.9497504 , 0.83399764, 0.50276944, ..., 0.13798924, 0.51200528,
#         0.28793741],
#        ...,
#        [0.963855  , 0.47101346, 0.1783421 , ..., 0.13451849, 0.37247753,
#         0.77881531],
#        [0.59424942, 0.16530143, 0.1210399 , ..., 0.150629  , 0.87451216,
#         0.76023416],
#        [0.63992226, 0.37987587, 0.10133306, ..., 0.14716751, 0.25507391,
#         0.07924751]])

# %%
s2.ndim
# Out:
# 2

# %%
s3=np.random.randint(100,200,size=(5,5))

# %%
s3
# Out:
# array([[138, 181, 188, 118, 149],
#        [129, 190, 106, 196, 169],
#        [108, 124, 130, 139, 145],
#        [198, 131, 122, 196, 122],
#        [161, 159, 105, 195, 144]])

# %%
sample=np.random.rand(100)

# %%
sinn=np.sin(sample)

# %%
sinn
# Out:
# array([0.55925705, 0.12941193, 0.39220944, 0.55069123, 0.8339515 ,
#        0.28100677, 0.22120741, 0.58364067, 0.23193965, 0.36006251,
#        0.41851072, 0.63256088, 0.74727134, 0.60034642, 0.79083257,
#        0.42696103, 0.54233877, 0.72883266, 0.69267438, 0.59134893,
#        0.42056882, 0.83773481, 0.05296989, 0.27596729, 0.68544276,
#        0.5386713 , 0.40379007, 0.66436246, 0.07982409, 0.42964265,
#        0.61121966, 0.09105685, 0.3005992 , 0.39301939, 0.80059533,
#        0.17549866, 0.74626946, 0.07500083, 0.76399013, 0.37611439,
#        0.06804432, 0.13065597, 0.20435429, 0.19618952, 0.43621495,
#        0.70566462, 0.30840185, 0.00125739, 0.08815413, 0.53193283,
#        0.71337017, 0.24449014, 0.83663213, 0.37689079, 0.0182361 ,
#        0.7935861 , 0.59571725, 0.46134438, 0.70526019, 0.72224461,
#        0.3590905 , 0.56980878, 0.52507287, 0.76770015, 0.61374891,
#        0.56370279, 0.50481978, 0.54373563, 0.34159573, 0.60837578,
# ...

# %%
fig,ax=plt.subplots(figsize=(5,5))

# %%
ax.plot(sample,sinn)

# %%
plt.show()

# %%
fig2,ax2=plt.subplots()
x=np.random.randint(100,200,size=(250))

# %%
x
# Out:
# array([180, 172, 141, 106, 126, 153, 101, 119, 188, 193, 104, 151, 107,
#        118, 126, 149, 113, 154, 120, 122, 105, 154, 123, 150, 112, 155,
#        186, 142, 198, 169, 157, 192, 100, 165, 198, 127, 116, 145, 102,
#        112, 147, 129, 135, 183, 148, 144, 122, 158, 198, 153, 122, 166,
#        181, 109, 177, 190, 175, 173, 199, 130, 140, 188, 120, 180, 188,
#        189, 194, 188, 115, 192, 101, 141, 189, 158, 115, 181, 181, 115,
#        133, 143, 124, 139, 125, 160, 135, 126, 107, 162, 159, 157, 154,
#        194, 188, 197, 178, 196, 171, 117, 156, 155, 103, 178, 148, 195,
#        133, 146, 185, 105, 149, 158, 164, 199, 147, 128, 197, 194, 191,
#        158, 160, 117, 151, 160, 165, 111, 173, 126, 114, 181, 102, 193,
#        163, 184, 168, 134, 145, 129, 110, 127, 126, 139, 179, 105, 176,
#        118, 160, 197, 163, 108, 100, 164, 116, 175, 157, 176, 150, 159,
#        121, 192, 185, 159, 128, 123, 154, 101, 129, 134, 158, 197, 152,
# ...

# %%
ax2.plot(x)

# %%
plt.show()

# %%
#fig.savefig("/Users/chowdaryadithyasaividivada/desktop/second.png")

# %% [markdown]
# ## most common plots in machine learnign are
# #### 1.line,2.scatter,3.bar,4.hist,5.subplots()

# %%
x=np.linspace(0,10,100)
# linspace method used to create the random numbers between two numbers

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
fig,ax=plt.subplots()

# %%
ax.plot(x,x**2)

# %%
plt.show()

# %% [markdown]
# # 2. scatter plotting

# %%
fig,ax=plt.subplots()

# %%
ax.scatter(x,x**2)

# %%
plt.show()

# %%
y=np.exp(x)
y
# Out:
# array([1.00000000e+00, 1.10628782e+00, 1.22387273e+00, 1.35395549e+00,
#        1.49786447e+00, 1.65706921e+00, 1.83319548e+00, 2.02804182e+00,
#        2.24359796e+00, 2.48206508e+00, 2.74587836e+00, 3.03773178e+00,
#        3.36060565e+00, 3.71779709e+00, 4.11295363e+00, 4.55011049e+00,
#        5.03373179e+00, 5.56875615e+00, 6.16064708e+00, 6.81544881e+00,
#        7.53984798e+00, 8.34124196e+00, 9.22781435e+00, 1.02086186e+01,
#        1.12936704e+01, 1.24940499e+01, 1.38220152e+01, 1.52911270e+01,
#        1.69163875e+01, 1.87143934e+01, 2.07035054e+01, 2.29040358e+01,
#        2.53384558e+01, 2.80316249e+01, 3.10110451e+01, 3.43071414e+01,
#        3.79535725e+01, 4.19875748e+01, 4.64503425e+01, 5.13874480e+01,
#        5.68493076e+01, 6.28916963e+01, 6.95763174e+01, 7.69714323e+01,
#        8.51525577e+01, 9.42032371e+01, 1.04215893e+02, 1.15292773e+02,
#        1.27546990e+02, 1.41103681e+02, 1.56101284e+02, 1.72692948e+02,
# ...

# %%
fig,ax=plt.subplots()
ax.scatter(x,y)

# %%
plt.show()

# %%
# sin function

# %%
fig,ax=plt.subplots()

# %%
ax.scatter(x,np.sin(x))

# %%
plt.show()

# %%
ax.scatter(x,np.cos(x))

# %%
plt.show()

# %% [markdown]
# ## Bar plot

# %%
fig,ax=plt.subplots()

# %%
butter={'almond':10,'peanut':8,'cashew':12}

# %%
butter
# Out:
# {'almond': 10, 'peanut': 8, 'cashew': 12}

# %%
butter.values()
# Out:
# dict_values([10, 8, 12])

# %%
butter.keys()
# Out:
# dict_keys(['almond', 'peanut', 'cashew'])

# %%
ax.bar(butter.keys(),butter.values())
ax.set(title='adithya\'s Butter store',xlabel='type of butter',ylabel='quantity')
# Out:
# [Text(0.5, 1.0, "adithya's Butter store"),
#  Text(0.5, 4.444444444444445, 'type of butter'),
#  Text(4.444444444444445, 0.5, 'quantity')]

# %%
plt.show()

# %% [markdown]
# To Make the bargraph horizontal

# %%
fig,ax=plt.subplots()

# %%
ax.barh(butter.keys(),butter.values())
ax.set(title='adityas butter house',xlabel='quantity',ylabel='types of butter')
# Out:
# [Text(0.5, 1.0, 'adityas butter house'),
#  Text(0.5, 4.444444444444445, 'quantity'),
#  Text(4.444444444444445, 0.5, 'types of butter')]

# %%
ax.barh(butter.keys(),butter.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Histogram

# %%
fig,ax=plt.subplots()

# %%
# data from a normal distribution

# %%
x=np.random.randn(100)

# %%
x
# Out:
# array([-1.26422263, -0.49572335, -0.42091625, -1.21667687, -0.17911788,
#        -0.76362373,  0.20538929, -1.01719026, -0.01048252, -0.10543289,
#         0.04865674,  0.22974756, -1.74619799,  1.24151137, -1.76915981,
#         0.63656399, -1.17089941, -0.22678915,  1.1932033 ,  1.27830376,
#         0.36780685, -0.54645458, -2.16601799,  0.05870335,  1.47863152,
#        -0.41329298, -0.21412402, -1.32788496,  0.02889302,  0.43382263,
#        -0.98176576,  0.25344129,  2.10295174,  0.94023551, -0.39529588,
#         0.45351482, -1.06907379, -1.21378289, -0.14029201, -1.35296154,
#         1.97216612,  1.02996741,  0.48308466,  1.47688524, -1.08866233,
#         0.36980291, -0.24205465, -0.12408888,  0.06075292, -0.62789914,
#        -0.37857916, -0.86168897,  1.31320575, -0.00557565, -1.09892069,
#        -0.42953305, -1.09694387,  0.31357329,  0.11146294,  1.63905352,
#        -1.29218227, -0.35027646,  0.99222849, -1.07141099, -0.61913166,
# ...

# %%
x.ndim
# Out:
# 1

# %%
x.dtype
# Out:
# dtype('float64')

# %%
x.shape
# Out:
# (100,)

# %%
ax.hist(x);

# %%
plt.show()

# %%
import pandas as pd
data=pd.read_csv('/Users/chowdaryadithyasaividivada/Downloads/car-sales.csv')

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data.plot()
# Out:
# <Axes: >

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2020',periods=1000))

# %%
ts
# Out:
# 2020-01-01   -1.265471
# 2020-01-02    0.167190
# 2020-01-03   -0.568479
# 2020-01-04    0.943770
# 2020-01-05    0.707392
#                 ...
# 2022-09-22   -0.485262
# 2022-09-23    0.531254
# 2022-09-24    0.179678
# 2022-09-25    2.444832
# 2022-09-26    1.864441
# Freq: D, Length: 1000, dtype: float64

# %%
# cummulative sum

# %%
ts.cumsum()
# Out:
# 2020-01-01    -1.265471
# 2020-01-02    -1.098280
# 2020-01-03    -1.666759
# 2020-01-04    -0.722989
# 2020-01-05    -0.015596
#                 ...
# 2022-09-22    15.613390
# 2022-09-23    16.144644
# 2022-09-24    16.324323
# 2022-09-25    18.769155
# 2022-09-26    20.633595
# Freq: D, Length: 1000, dtype: float64

# %%
ts=ts.cumsum()

# %%
ts.plot()
# Out:
# <Axes: >

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data['Price']
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
data['Price']=data['Price'].str.replace('$','')

# %%
data.Price
# Out:
# 0     4,000.00
# 1     5,000.00
# 2     7,000.00
# 3    22,000.00
# 4     3,500.00
# 5     4,500.00
# 6     7,500.00
# 7     7,000.00
# 8     6,250.00
# 9     9,700.00
# Name: Price, dtype: object

# %%
data['Price']=data['Price'].str.replace('.','')

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   4,00000
# 1   Honda    Red          87899      4   5,00000
# 2  Toyota   Blue          32549      3   7,00000
# 3     BMW  Black          11179      5  22,00000
# 4  Nissan  White         213095      4   3,50000
# 5  Toyota  Green          99213      4   4,50000
# 6   Honda   Blue          45698      4   7,50000
# 7   Honda   Blue          54738      4   7,00000
# 8  Toyota  White          60000      4   6,25000
# 9  Nissan  White          31600      4   9,70000

# %%
data['Price']=data['Price'].str.replace(',','')

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# convert to string

# %%
data['Price']=data['Price'].str[:-2]

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
data['saledate']=pd.date_range('1/1/2022',periods=len(data))

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price   saledate
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
data['total']=data['Price'].astype(int).cumsum()

# %%
type(data['Price'][0])
# Out:
# str

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price   saledate  total
# 0  Toyota  White         150043      4   4000 2022-01-01   4000
# 1   Honda    Red          87899      4   5000 2022-01-02   9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03  16000
# 3     BMW  Black          11179      5  22000 2022-01-04  38000
# 4  Nissan  White         213095      4   3500 2022-01-05  41500
# 5  Toyota  Green          99213      4   4500 2022-01-06  46000
# 6   Honda   Blue          45698      4   7500 2022-01-07  53500
# 7   Honda   Blue          54738      4   7000 2022-01-08  60500
# 8  Toyota  White          60000      4   6250 2022-01-09  66750
# 9  Nissan  White          31600      4   9700 2022-01-10  76450

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price   saledate  total
# 0  Toyota  White         150043      4   4000 2022-01-01   4000
# 1   Honda    Red          87899      4   5000 2022-01-02   9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03  16000
# 3     BMW  Black          11179      5  22000 2022-01-04  38000
# 4  Nissan  White         213095      4   3500 2022-01-05  41500
# 5  Toyota  Green          99213      4   4500 2022-01-06  46000
# 6   Honda   Blue          45698      4   7500 2022-01-07  53500
# 7   Honda   Blue          54738      4   7000 2022-01-08  60500
# 8  Toyota  White          60000      4   6250 2022-01-09  66750
# 9  Nissan  White          31600      4   9700 2022-01-10  76450

# %%
data.plot()
# Out:
# <Axes: >

# %%
total=pd.DataFrame({'total':data['total'],'saledate':data.saledate})

# %%
total
# Out:
#    total   saledate
# 0   4000 2022-01-01
# 1   9000 2022-01-02
# 2  16000 2022-01-03
# 3  38000 2022-01-04
# 4  41500 2022-01-05
# 5  46000 2022-01-06
# 6  53500 2022-01-07
# 7  60500 2022-01-08
# 8  66750 2022-01-09
# 9  76450 2022-01-10

# %%
total.plot(x='saledate',y='total')
# Out:
# <Axes: xlabel='saledate'>

# %%
data['Price']=data['Price'].astype('int')
data.plot(x='Odometer (KM)',y='Price',kind='scatter')
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>
