# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introduction to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
# plt.plot(3,3)

# %%
plt.plot();

# %%
plt.show()

# %%
plt.plot([1,2,3,4,5]);

# %%
plt.show()

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %%
plt.plot(x,y)

# %%
plt.show()

# %% [markdown]
# ## the above plotting is called as the stateless plotting

# %%
plt.show()

# %% [markdown]
# ### pyplot api is less flexible than object-oriented api

# %%
#try to use the objectoriented interface than pyplot interface

# %%
fig=plt.figure()

# %%
ax=fig.add_subplot()

# %%
plt.show()

# %%
#second method

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])

# %%
ax.plot(x,y)
plt.show()

# %%
## 3rd method(recommended)

# %%
fig,ax=plt.subplots()
ax.plot(x,y);

# %%
plt.show()

# %%
sfig,sax=plt.subplots()

# %%
sax.plot(x,[50,100,200,400])

# %%
plt.show()

# %% [markdown]
# ## use always method 3 for the plotting

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# the both outputs above will represent the object oriented display

# %% [markdown]
# # matplotlob example workflow

# %% [markdown]
# # 0. preparing the import if the matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.prepare data

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %% [markdown]
# # 2.setupplot

# %%
fig,ax=plt.subplots(figsize=(5,10))

# %%
# here figsize is the width and height respectively of the plot

# %% [markdown]
# # 3. plot the data

# %%
ax.plot(x,y)

# %% [markdown]
# # 4. customize the plot

# %%
ax.set(title='sample plot',xlabel='x-axis',ylabel='y-axis')
# Out:
# [Text(0.5, 1.0, 'sample plot'),
#  Text(0.5, 80.7222222222222, 'x-axis'),
#  Text(29.47222222222222, 0.5, 'y-axis')]

# %%
plt.show()

# %%
fig.savefig("/Users/chowdaryadithyasaividivada/desktop/sample.png")

# %%
import numpy as np

# %%
s1=np.random.rand(100)

# %%
s1
# Out:
# array([1.86304893e-01, 1.21512997e-01, 2.05298612e-01, 4.23077323e-01,
#        9.23840184e-01, 6.35433520e-01, 7.79753885e-01, 7.92119424e-01,
#        7.74208075e-01, 5.45946249e-01, 9.08797881e-01, 3.11875469e-01,
#        5.41283307e-01, 3.41413819e-01, 2.16486074e-01, 4.33632155e-01,
#        7.33413917e-01, 7.04354175e-01, 6.84726125e-01, 3.69518453e-01,
#        2.62641778e-01, 5.00539616e-01, 3.77493329e-01, 3.63243152e-01,
#        1.96699244e-01, 5.24537462e-01, 3.69895400e-02, 6.65173090e-01,
#        5.15353871e-01, 4.01761210e-01, 7.93914275e-01, 2.18482891e-01,
#        2.24629269e-01, 8.76283660e-01, 7.73055155e-01, 3.27740234e-01,
#        8.51139005e-01, 4.51132054e-01, 1.39411601e-02, 7.47899826e-01,
#        4.65856782e-01, 8.94607972e-02, 1.81833410e-01, 8.37213093e-01,
#        8.75598169e-01, 7.83136106e-01, 3.82364823e-01, 5.02003721e-01,
#        2.03534961e-02, 8.00728396e-01, 7.76542437e-01, 6.60872372e-01,
#        3.33139747e-03, 1.45750918e-01, 4.25206516e-01, 1.18600525e-01,
#        1.74747969e-01, 9.70158326e-01, 4.57702369e-02, 7.21937005e-01,
#        6.37295915e-02, 4.66452818e-01, 9.46273404e-01, 3.01014694e-03,
#        7.86562235e-01, 1.26397315e-01, 4.46627706e-01, 8.86138373e-02,
#        7.05997684e-02, 3.60194686e-01, 9.16643272e-01, 8.62566637e-01,
#        7.33634263e-01, 4.35127741e-01, 8.58859394e-01, 6.72576951e-01,
#        7.55352482e-01, 4.85140965e-04, 9.66376613e-02, 4.02632232e-01,
#        7.04704411e-01, 3.15472866e-01, 5.78384069e-01, 2.44100907e-01,
#        4.85684086e-01, 8.12482557e-01, 6.01621176e-01, 7.15624159e-01,
#        5.72322853e-01, 3.51241625e-02, 2.06541517e-01, 3.90413229e-01,
#        9.95322452e-01, 9.09133588e-01, 6.16158801e-01, 8.80517687e-01,
#        2.79057260e-01, 5.22088259e-01, 9.40337842e-01, 1.54712150e-01])

# %%
s1.ndim
# Out:
# 1

# %%
s2=np.random.rand(100,200)

# %%
s2
# Out:
# array([[0.87717797, 0.19911482, 0.73735048, ..., 0.11239845, 0.13733899,
#         0.63604529],
#        [0.83977741, 0.12482785, 0.97284315, ..., 0.36988326, 0.56366011,
#         0.38952026],
#        [0.2844523 , 0.98518605, 0.64293258, ..., 0.88953594, 0.82280385,
#         0.60044944],
#        ...,
#        [0.255732  , 0.47909119, 0.74392132, ..., 0.05067692, 0.88944956,
#         0.67695015],
#        [0.34663334, 0.98513717, 0.04781634, ..., 0.46380878, 0.29262007,
#         0.33419203],
#        [0.69099357, 0.34475408, 0.25868952, ..., 0.46042267, 0.05265592,
#         0.06070182]])

# %%
s2.ndim
# Out:
# 2

# %%
s3=np.random.randint(100,200,size=(5,5))

# %%
s3
# Out:
# array([[148, 133, 139, 180, 142],
#        [163, 144, 177, 131, 138],
#        [191, 143, 129, 120, 178],
#        [120, 192, 137, 161, 101],
#        [197, 137, 199, 199, 122]])

# %%
sample=np.random.rand(100)

# %%
sinn=np.sin(sample)

# %%
sinn
# Out:
# array([0.26304057, 0.82406737, 0.73530252, 0.37337224, 0.77435068,
#        0.1215828 , 0.67664286, 0.24955967, 0.28466545, 0.79653881,
#        0.2480981 , 0.32824346, 0.39240362, 0.49999791, 0.19053682,
#        0.36438945, 0.27571602, 0.75591446, 0.47424227, 0.27202933,
#        0.66364367, 0.82622155, 0.55984845, 0.7241136 , 0.80713018,
#        0.35266501, 0.66619835, 0.19851912, 0.46318586, 0.80723732,
#        0.03491196, 0.65647091, 0.77970755, 0.42983431, 0.04524047,
#        0.37295042, 0.19259173, 0.37209026, 0.16144296, 0.61741611,
#        0.75810462, 0.49564492, 0.40896369, 0.59930611, 0.46720261,
#        0.60924569, 0.57843979, 0.54842648, 0.77545913, 0.71657919,
#        0.77928661, 0.1761344 , 0.0798911 , 0.63590511, 0.62827998,
#        0.61856324, 0.44913561, 0.74979166, 0.8204149 , 0.20316164,
#        0.49288927, 0.41716233, 0.67458281, 0.4744451 , 0.56925717,
#        0.33754909, 0.14697386, 0.8265698 , 0.05120726, 0.61825915,
#        0.42805294, 0.64240003, 0.76695275, 0.61849091, 0.05173863,
#        0.40998777, 0.52181462, 0.6679753 , 0.65306682, 0.60049335,
#        0.43525251, 0.24155315, 0.31411862, 0.63705104, 0.61165529,
#        0.76919913, 0.66354045, 0.1935286 , 0.551233  , 0.42747292,
#        0.80699088, 0.58161805, 0.51199223, 0.55946363, 0.30377195,
#        0.74770442, 0.53899155, 0.75064735, 0.13347736, 0.079446  ])

# %%
fig,ax=plt.subplots(figsize=(5,5))

# %%
ax.plot(sample,sinn)

# %%
plt.show()

# %%
fig2,ax2=plt.subplots()
x=np.random.randint(100,200,size=(250))

# %%
x
# Out:
# array([194, 131, 115, 159, 109, 149, 128, 180, 111, 186, 143, 127, 133,
#        100, 139, 132, 131, 100, 174, 132, 108, 188, 176, 156, 166, 185,
#        114, 129, 140, 176, 130, 176, 194, 186, 137, 175, 141, 145, 167,
#        134, 103, 127, 110, 153, 108, 191, 120, 116, 154, 190, 197, 110,
#        182, 122, 139, 186, 158, 103, 177, 198, 196, 154, 162, 122, 109,
#        139, 122, 156, 125, 118, 149, 134, 102, 134, 183, 126, 163, 176,
#        169, 169, 170, 183, 178, 138, 197, 144, 183, 120, 186, 188, 187,
#        192, 102, 116, 145, 121, 199, 184, 110, 112, 159, 185, 111, 178,
#        143, 199, 150, 189, 175, 189, 152, 177, 197, 126, 119, 132, 139,
#        102, 120, 150, 148, 169, 123, 183, 184, 151, 103, 181, 190, 129,
#        146, 141, 110, 122, 178, 161, 145, 113, 108, 174, 142, 124, 149,
#        190, 133, 146, 175, 182, 137, 133, 107, 189, 140, 112, 145, 162,
#        103, 198, 189, 144, 153, 198, 168, 163, 110, 118, 182, 149, 123,
#        199, 116, 101, 100, 168, 177, 118, 128, 108, 109, 165, 124, 193,
#        151, 111, 145, 152, 198, 199, 146, 121, 128, 128, 194, 130, 155,
#        134, 138, 189, 148, 165, 148, 105, 144, 103, 165, 144, 128, 185,
#        143, 184, 138, 133, 169, 162, 166, 125, 117, 166, 182, 129, 190,
#        155, 115, 182, 126, 128, 138, 148, 160, 171, 180, 165, 193, 125,
#        178, 191, 142, 166, 198, 157, 190, 181, 148, 149, 150, 198, 138,
#        193, 118, 160])

# %%
ax2.plot(x)

# %%
plt.show()

# %%
fig.savefig("/Users/chowdaryadithyasaividivada/desktop/second.png")

# %% [markdown]
# ## most common plots in machine learnign are
# #### 1.line,2.scatter,3.bar,4.hist,5.subplots()

# %%
x=np.linspace(0,10,100)
# linspace method used to create the random numbers between two numbers

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
fig,ax=plt.subplots()

# %%
ax.plot(x,x**2)

# %%
plt.show()

# %% [markdown]
# # 2. scatter plotting

# %%
fig,ax=plt.subplots()

# %%
ax.scatter(x,x**2)

# %%
plt.show()

# %%
y=np.exp(x)
y
# Out:
# array([1.00000000e+00, 1.10628782e+00, 1.22387273e+00, 1.35395549e+00,
#        1.49786447e+00, 1.65706921e+00, 1.83319548e+00, 2.02804182e+00,
#        2.24359796e+00, 2.48206508e+00, 2.74587836e+00, 3.03773178e+00,
#        3.36060565e+00, 3.71779709e+00, 4.11295363e+00, 4.55011049e+00,
#        5.03373179e+00, 5.56875615e+00, 6.16064708e+00, 6.81544881e+00,
#        7.53984798e+00, 8.34124196e+00, 9.22781435e+00, 1.02086186e+01,
#        1.12936704e+01, 1.24940499e+01, 1.38220152e+01, 1.52911270e+01,
#        1.69163875e+01, 1.87143934e+01, 2.07035054e+01, 2.29040358e+01,
#        2.53384558e+01, 2.80316249e+01, 3.10110451e+01, 3.43071414e+01,
#        3.79535725e+01, 4.19875748e+01, 4.64503425e+01, 5.13874480e+01,
#        5.68493076e+01, 6.28916963e+01, 6.95763174e+01, 7.69714323e+01,
#        8.51525577e+01, 9.42032371e+01, 1.04215893e+02, 1.15292773e+02,
#        1.27546990e+02, 1.41103681e+02, 1.56101284e+02, 1.72692948e+02,
#        1.91048105e+02, 2.11354190e+02, 2.33818566e+02, 2.58670631e+02,
#        2.86164167e+02, 3.16579931e+02, 3.50228521e+02, 3.87453546e+02,
#        4.28635137e+02, 4.74193830e+02, 5.24594856e+02, 5.80352898e+02,
#        6.42037340e+02, 7.10278087e+02, 7.85771994e+02, 8.69289984e+02,
#        9.61684918e+02, 1.06390031e+03, 1.17697995e+03, 1.30207858e+03,
#        1.44047367e+03, 1.59357847e+03, 1.76295644e+03, 1.95033723e+03,
#        2.15763432e+03, 2.38696456e+03, 2.64066981e+03, 2.92134083e+03,
#        3.23184377e+03, 3.57534939e+03, 3.95536547e+03, 4.37577263e+03,
#        4.84086395e+03, 5.35538880e+03, 5.92460138e+03, 6.55431433e+03,
#        7.25095809e+03, 8.02164659e+03, 8.87424989e+03, 9.81747453e+03,
#        1.08609525e+04, 1.20153394e+04, 1.32924236e+04, 1.47052462e+04,
#        1.62682347e+04, 1.79973499e+04, 1.99102489e+04, 2.20264658e+04])

# %%
fig,ax=plt.subplots()
ax.scatter(x,y)

# %%
plt.show()

# %%
# sin function

# %%
fig,ax=plt.subplots()

# %%
ax.scatter(x,np.sin(x))

# %%
plt.show()

# %%
ax.scatter(x,np.cos(x))

# %%
plt.show()

# %% [markdown]
# ## Bar plot

# %%
fig,ax=plt.subplots()

# %%
butter={'almond':10,'peanut':8,'cashew':12}

# %%
butter
# Out:
# {'almond': 10, 'peanut': 8, 'cashew': 12}

# %%
butter.values()
# Out:
# dict_values([10, 8, 12])

# %%
butter.keys()
# Out:
# dict_keys(['almond', 'peanut', 'cashew'])

# %%
ax.bar(butter.keys(),butter.values())
ax.set(title='adithya\'s Butter store',xlabel='type of butter',ylabel='quantity')
# Out:
# [Text(0.5, 1.0, "adithya's Butter store"),
#  Text(0.5, 4.444444444444445, 'type of butter'),
#  Text(4.444444444444445, 0.5, 'quantity')]

# %%
plt.show()
